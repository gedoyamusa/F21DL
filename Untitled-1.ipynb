# %%
import json
import pandas as pd
import matplotlib.pyplot as plt
import tkinter as tk
import pycountry
import pycountry_convert as pc
from sklearn.preprocessing import LabelEncoder
import user_agents as ua
import gzip

# %%
data = []
df=pd.DataFrame()
with gzip.open('/Users/kevinc/Downloads/sample_3m_lines.json.gz') as file:
    for i in file:
        dataDictionary = json.loads(i)
        data.append(dataDictionary)

# %%
df=pd.DataFrame(data)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Untitled-1.ipynb Cell 4 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W5sdW50aXRsZWQ%3D?line=0'>1</a> df=pd.DataFrame(data)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:729, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     720         columns = ensure_index(columns)  # type: ignore[arg-type]
#     721     arrays, columns, index = nested_data_to_arrays(
#     722         # error: Argument 3 to "nested_data_to_arrays" has incompatible
#     723         # type "Optional[Collection[Any]]"; expected "Optional[Index]"
#    (...)
#     727         dtype,
#     728     )
# --> 729     mgr = arrays_to_mgr(
#     730         arrays,
#     731         columns,
#     732         index,
#     733         dtype=dtype,
#     734         typ=manager,
#     735     )
#     736 else:
#     737     mgr = ndarray_to_mgr(
#     738         data,
#     739         index,
#    (...)
#     743         typ=manager,
#     744     )
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/construction.py:156, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     153 axes = [columns, index]
#     155 if typ == "block":
# --> 156     return create_block_manager_from_column_arrays(
#     157         arrays, axes, consolidate=consolidate
#     158     )
#     159 elif typ == "array":
#     160     return ArrayManager(arrays, [index, columns])
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/managers.py:1954, in create_block_manager_from_column_arrays(arrays, axes, consolidate)
#    1937 def create_block_manager_from_column_arrays(
#    1938     arrays: list[ArrayLike],
#    1939     axes: list[Index],
#    (...)
#    1950     # These last three are sufficient to allow us to safely pass
#    1951     #  verify_integrity=False below.
#    1953     try:
# -> 1954         blocks = _form_blocks(arrays, consolidate)
#    1955         mgr = BlockManager(blocks, axes, verify_integrity=False)
#    1956     except ValueError as e:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/managers.py:2028, in _form_blocks(arrays, consolidate)
#    2025 if issubclass(dtype.type, (str, bytes)):
#    2026     dtype = np.dtype(object)
# -> 2028 values, placement = _stack_arrays(list(tup_block), dtype)
#    2029 if is_dtlike:
#    2030     values = ensure_wrapped_if_datetimelike(values)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/managers.py:2069, in _stack_arrays(tuples, dtype)
#    2067 stacked = np.empty(shape, dtype=dtype)
#    2068 for i, arr in enumerate(arrays):
# -> 2069     stacked[i] = arr
#    2071 return stacked, placement
#
# KeyboardInterrupt:

# %%
df
# Out:
#                ts      visitor_uuid visitor_source visitor_device  \
# 0      1394759358  d4744ab22c700ca7       external        browser
# 1      1394759159  4c26a634fca5f33a       external        browser
# 2      1394759159  4c26a634fca5f33a       external        browser
# 3      1394759159  4c26a634fca5f33a       external        browser
# 4      1394759159  4c26a634fca5f33a       external        browser
# ...           ...               ...            ...            ...
# 10096  1394759159  4c26a634fca5f33a       external        browser
# 10097  1394759159  4c26a634fca5f33a       external        browser
# 10098  1394759159  4c26a634fca5f33a       external        browser
# 10099  1394759159  4c26a634fca5f33a       external        browser
# 10100  1394759159  4c26a634fca5f33a       external        browser
#
#                                        visitor_useragent        visitor_ip  \
# 0      Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.3...  bf4ab9c301b2ba2e
# 1      Mozilla/5.0 (iPad; CPU OS 7_0_4 like Mac OS X)...  e52bf1dd0ae8a275
# 2      Mozilla/5.0 (iPad; CPU OS 7_0_4 like Mac OS X)...  e52bf1dd0ae8a275
# 3      Mozilla/5.0 (iPad; CPU OS 7_0_4 like Mac OS X)...  e52bf1dd0ae8a275
# 4      Mozilla/5.0 (iPad; CPU OS 7_0_4 like Mac OS X)...  e52bf1dd0ae8a275
# ...                                                  ...               ...
# 10096  Mozilla/5.0 (iPad; CPU OS 7_0_4 like Mac OS X)...  e52bf1dd0ae8a275
# 10097  Mozilla/5.0 (iPad; CPU OS 7_0_4 like Mac OS X)...  e52bf1dd0ae8a275
# 10098  Mozilla/5.0 (iPad; CPU OS 7_0_4 like Mac OS X)...  e52bf1dd0ae8a275
# 10099  Mozilla/5.0 (iPad; CPU OS 7_0_4 like Mac OS X)...  e52bf1dd0ae8a275
# 10100  Mozilla/5.0 (iPad; CPU OS 7_0_4 like Mac OS X)...  e52bf1dd0ae8a275
#
#       visitor_country  visitor_referrer env_type  \
# 0                  MX  f2270e250aa405b2   reader
# 1                  US  bdc1ab012df2a239   reader
# 2                  US  bdc1ab012df2a239   reader
# 3                  US  bdc1ab012df2a239   reader
# 4                  US  bdc1ab012df2a239   reader
# ...               ...               ...      ...
# 10096              US  bdc1ab012df2a239   reader
# 10097              US  bdc1ab012df2a239   reader
# 10098              US  bdc1ab012df2a239   reader
# 10099              US  bdc1ab012df2a239   reader
# 10100              US  bdc1ab012df2a239   reader
#
#                                           env_doc_id    event_type  \
# 0      140219193453-f551afddbf7740e29e3d610ffa49f74f  pagereadtime
# 1      130107151047-1cac70c2cbe941359e29d69402c82487      pageread
# 2      130107151047-1cac70c2cbe941359e29d69402c82487      pageread
# 3      130107151047-1cac70c2cbe941359e29d69402c82487      pageread
# 4      130107151047-1cac70c2cbe941359e29d69402c82487      pageread
# ...                                              ...           ...
# 10096  130107151047-1cac70c2cbe941359e29d69402c82487      pageread
# 10097  130107151047-1cac70c2cbe941359e29d69402c82487      pageread
# 10098  130107151047-1cac70c2cbe941359e29d69402c82487      pageread
# 10099  130107151047-1cac70c2cbe941359e29d69402c82487      pageread
# 10100  130107151047-1cac70c2cbe941359e29d69402c82487      pageread
#
#        event_readtime subject_type  \
# 0               899.0          doc
# 1                 NaN          doc
# 2                 NaN          doc
# 3                 NaN          doc
# 4                 NaN          doc
# ...               ...          ...
# 10096             NaN          doc
# 10097             NaN          doc
# 10098             NaN          doc
# 10099             NaN          doc
# 10100             NaN          doc
#
#                                       subject_doc_id  subject_page
# 0      140219193453-f551afddbf7740e29e3d610ffa49f74f            78
# 1      130107151047-1cac70c2cbe941359e29d69402c82487             3
# 2      130107151047-1cac70c2cbe941359e29d69402c82487             3
# 3      130107151047-1cac70c2cbe941359e29d69402c82487             3
# 4      130107151047-1cac70c2cbe941359e29d69402c82487             3
# ...                                              ...           ...
# 10096  130107151047-1cac70c2cbe941359e29d69402c82487             3
# 10097  130107151047-1cac70c2cbe941359e29d69402c82487             3
# 10098  130107151047-1cac70c2cbe941359e29d69402c82487             3
# 10099  130107151047-1cac70c2cbe941359e29d69402c82487             3
# 10100  130107151047-1cac70c2cbe941359e29d69402c82487             3
#
# [10101 rows x 15 columns]

# %%
divi
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Untitled-1.ipynb Cell 4 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W3sdW50aXRsZWQ%3D?line=0'>1</a> df=pd.concat(data)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/reshape/concat.py:347, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     143 @deprecate_nonkeyword_arguments(version=None, allowed_args=["objs"])
#     144 def concat(
#     145     objs: Iterable[NDFrame] | Mapping[Hashable, NDFrame],
#    (...)
#     154     copy: bool = True,
#     155 ) -> DataFrame | Series:
#     156     """
#     157     Concatenate pandas objects along a particular axis with optional set logic
#     158     along the other axes.
#    (...)
#     345     ValueError: Indexes have overlapping values: ['a']
#     346     """
# --> 347     op = _Concatenator(
#     348         objs,
#     349         axis=axis,
#     350         ignore_index=ignore_index,
#     351         join=join,
#     352         keys=keys,
#     353         levels=levels,
#     354         names=names,
#     355         verify_integrity=verify_integrity,
#     356         copy=copy,
#     357         sort=sort,
#     358     )
#     360     return op.get_result()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/reshape/concat.py:437, in _Concatenator.__init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     432     if not isinstance(obj, (ABCSeries, ABCDataFrame)):
#     433         msg = (
#     434             f"cannot concatenate object of type '{type(obj)}'; "
#     435             "only Series and DataFrame objs are valid"
#     436         )
# --> 437         raise TypeError(msg)
#     439     ndims.add(obj.ndim)
#     441 # get the sample
#     442 # want the highest ndim that we have, and must be non-empty
#     443 # unless all objs are empty
#
# TypeError: cannot concatenate object of type '<class 'dict'>'; only Series and DataFrame objs are valid
